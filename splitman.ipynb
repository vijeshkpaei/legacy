# %%
######eroor#####################################################333

with open('person1.txt') as fo:
    op=''
    start=0
    cntr = 1
    for x in fo.read() .split("\n"):
        if (x=='**'):
            if (start==1):
                opf=open(str(cntr) + '.txt','w')
                opf.write(op)
                opf.close()
                op=''
                cntr+=1
            else:
                start=1
    else:
        op=op + '\n' + x
        fo.close()
        print 'completed'
# Out:
# completed

# %%
#################try ##############################

with open('inp.txt') as fo:
    op=''
    start=0
    cntr = 1
   # print fo.read()
    for x in fo.read().split("\n"):
        #print x + "\n-----------------\n"
        if (x=='**'):
             if (start==1):
                with open(str(cntr) + '.txt','w') as opf:
                    opf.write(op)
                    opf.close()
                    op=''
                    cntr+=1
             else:   
                start=1
            
            
        else:
            op= op + '\n' + x
    
    
    
    fo.close()

# %%
##################working code####################

with open('org.txt') as fo:
    #op=''
    #start=0
    cntr = 1
   # print fo.read()
    for x in fo.read().split("\n"):
        #print x + "\n-----------------\n"
        #if (x=='****'):
        #     if (start==1):
        with open(str(cntr) + '.txt','w') as opf:
            opf.write(x)
            opf.close()
            #op=''
            cntr+=1
            # else:   
            #    start=1
            
            
        #else:
        #    op= op + '\n' + x
    
    
    
    fo.close()

# %%
with open('person1.txt') as fo:
    #print fo.read()
    for x in fo.read().split("\n"):
         print x + "\n****"
# Out:
# 807,242,38,99
# ****
# 807,242,38,99
# ****
# 808,242,38,99
# ****
# 808,242,38,99
# ****
# 808,243,38,99
# ****
# 808,243,38,98
# ****
# 808,244,38,98
# ****
# 808,244,39,98
# ****
# 808,245,41,98
# ****
# 808,245,42,98
# ****
# 808,245,42,98
# ****
# 808,244,43,99
# ****
# 808,244,43,99
# ****
# 809,244,43,99
# ****
# 809,243,43,100
# ****
# 810,243,43,100
# ****
# 810,243,43,100
# ****
# 810,243,43,101
# ****
# 810,243,43,101
# ****
# 810,242,43,102
# ****
# 810,241,43,102
# ****
# 810,240,43,103
# ****
# 810,238,43,105
# ****
# 811,237,44,107
# ****
# 811,235,44,109
# ****
# 811,235,42,109
# ****
# 811,235,39,109
# ****
# 811,235,37,109
# ****
# 811,235,37,109
# ****
# 811,235,37,109
# ****
# 811,235,37,109
# ****
# 811,233,37,109
# ****
# 811,230,37,109
# ****
# 811,228,37,109
# ****
# 811,226,38,109
# ****
# 810,224,40,109
# ****
# 810,222,41,109
# ****
# 810,222,41,109
# ****
# 811,223,41,109
# ****
# 811,223,41,109
# ****
# 810,221,41,109
# ****
# 810,218,41,109
# ****
# ...

# %%
### delete working  code########
with open('1.txt', 'r') as fin:
    data = fin.read().splitlines(True)
with open('1.txt', 'w') as fout:
    fout.writelines(data[1:])

# %%
import string, os
#import os
import pdb
for f in os.listdir('.'):
    if f != "org.py":
		#filename = f
		#pdb.set_trace()
		#filename_without_ext =  str(f.split(".")[:-1])
		#fname = filename
		#fname_out = filename_without_ext + "_out.txt"
		fname = f
		fname_out = f
		
		
		#image_width = 1280
		#image_height = 720

		content = []

		with open(fname) as f:
			#content = f.readlines()
            data = f.read().splitlines(True)
        with open(fname_out) as f:
            f.writelines(data[1:])
            
            
		# you may also want to remove whitespace characters like `\n` at the end of each line
		#content = [x.strip() for x in content] 
        

		#print(content)

		#new_content = []

    
    
    
    
    
    
    
    
    
    
    
    
    #with open(f, 'r') as fin:
     #   data = fin.read().splitlines(True)
    #with open(f, 'w') as fout:
     #   fout.writelines(data[1:])
# Out:
#   File "<ipython-input-1-fcfb0a861e8c>", line 22
#     data = f.read().splitlines(True)
#                                     ^
# IndentationError: unindent does not match any outer indentation level
